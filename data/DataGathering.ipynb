# %% [markdown]
# ## Gathering of data

# %%
import pandas as pd
from pyjstat import pyjstat
import requests
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
kveite_prices = pd.read_excel("Fersk_kveite.xlsx", skiprows=4)

# %%
kveite_prices = kveite_prices.tail(-13)
kveite_prices = kveite_prices[kveite_prices.KalenderUkeBeskrivelse != 53]
kveite_prices = kveite_prices.reset_index(drop=True)
kveite_prices
# Out:
#      OMSETNING_ÅR  KalenderUkeBeskrivelse    100+ KG   -20,0 KG   20-40 KG  \
# 0            2013                      14  30.000000        NaN        NaN
# 1            2013                      15  30.000000        NaN        NaN
# 2            2013                      16  30.000000        NaN        NaN
# 3            2013                      17  26.851158        NaN        NaN
# 4            2013                      18  30.000000        NaN        NaN
# ..            ...                     ...        ...        ...        ...
# 502          2022                      48        NaN  80.780069  80.787690
# 503          2022                      49        NaN  81.475444  73.848064
# 504          2022                      50        NaN  81.294761  76.470526
# 505          2022                      51        NaN  79.262251  77.425490
# 506          2022                      52        NaN  79.182888        NaN
#
#        -4,0 KG   -40,0 KG     40+ KG   40-60 KG     60+ KG  60-99 KG  \
# 0          NaN  49.764852  39.609989        NaN  35.000000       NaN
# 1          NaN  50.153008  39.726203        NaN  34.290482       NaN
# 2          NaN  49.744720  40.588599        NaN  35.190833       NaN
# 3          NaN  49.767285  39.056457        NaN  34.354839       NaN
# 4    25.000000  50.088888  39.478360        NaN  35.000000       NaN
# ..         ...        ...        ...        ...        ...       ...
# 502  10.117788        NaN        NaN  76.049203  60.392543       NaN
# 503   3.099337        NaN        NaN  74.776444  61.019040       NaN
# 504   5.151143        NaN        NaN  74.809421  59.513327       NaN
# 505        NaN        NaN        NaN  79.891625  63.484762       NaN
# 506        NaN        NaN        NaN        NaN        NaN       NaN
#
#       Totalsum
# 0    47.577612
# 1    47.924958
# 2    47.092639
# 3    47.193296
# 4    48.987917
# ..         ...
# 502  76.897925
# 503  73.642666
# 504  73.193629
# 505  74.156841
# 506  79.182888
#
# [507 rows x 12 columns]

# %%
salmon_prices = pd.read_excel("nasdaq.with.weight.xls", skiprows=1)

# %%
salmon_prices = salmon_prices.head(-5)
salmon_prices = salmon_prices[salmon_prices.Week != 53]
salmon_prices = salmon_prices.reset_index(drop=True)
salmon_prices
# Out:
#        Year  Week  3-4 Kg  4-5 Kg  5-6 Kg  3-4 Kg Weight  4-5 Kg Weight  \
# 0    2013.0  14.0   39.70   40.53   40.85            0.3            0.4
# 1    2013.0  15.0   41.75   42.91   43.17            0.3            0.4
# 2    2013.0  16.0   42.73   43.94   44.74            0.3            0.4
# 3    2013.0  17.0   42.54   43.54   44.23            0.3            0.4
# 4    2013.0  18.0   41.52   42.76   43.34            0.3            0.4
# ..      ...   ...     ...     ...     ...            ...            ...
# 502  2022.0  48.0   79.12   81.59   87.05            0.3            0.4
# 503  2022.0  49.0   76.47   78.43   82.38            0.3            0.4
# 504  2022.0  50.0   74.60   77.80   81.83            0.3            0.4
# 505  2022.0  51.0   72.88   75.19   79.62            0.3            0.4
# 506  2022.0  52.0   82.30   85.97   91.88            0.3            0.4
#
#      5-6 Kg weight  Nasdaq 3-6 kg  Deduction Factor  \
# 0              0.3          40.38             -0.75
# 1              0.3          42.64             -0.75
# 2              0.3          43.82             -0.75
# 3              0.3          43.45             -0.75
# 4              0.3          42.56             -0.75
# ..             ...            ...               ...
# 502            0.3          82.49              0.00
# 503            0.3          79.03              0.00
# 504            0.3          78.05              0.00
# 505            0.3          75.83              0.00
# 506            0.3          86.64              0.00
#
#      Nasdaq 3-6 kg in FPI (FCA Oslo)  Currency  Nasdaq 3-6 kg in FPI (EUR)
# 0                              39.63    7.4500                        5.42
# 1                              41.89    7.4800                        5.70
# 2                              43.07    7.5500                        5.80
# 3                              42.70    7.6500                        5.68
# 4                              41.81    7.6000                        5.60
# ..                               ...       ...                         ...
# 502                            82.49   10.2942                        8.01
# 503                            79.03   10.4651                        7.55
# 504                            78.05   10.4539                        7.47
# 505                            75.83   10.4639                        7.25
# 506                            86.64   10.5007                        8.25
#
# [507 rows x 13 columns]

# %%
torsk_prices = pd.read_excel("Fersk_torsk.xlsx", skiprows=4)

# %%
torsk_prices = torsk_prices.tail(-13)
torsk_prices = torsk_prices[torsk_prices.KalenderUkeBeskrivelse != 53]
torsk_prices = torsk_prices.reset_index(drop=True)
torsk_prices
# Out:
#      OMSETNING_ÅR  KalenderUkeBeskrivelse    -1,0 KG  1,0-2,5 KG    2,5+ KG  \
# 0            2013                      14   8.000000    9.630678  10.420998
# 1            2013                      15   8.000000    9.826467  10.500865
# 2            2013                      16   8.006991    9.537936  10.553869
# 3            2013                      17   8.049334    9.585848  10.353178
# 4            2013                      18   7.992742    9.666591  10.530068
# ..            ...                     ...        ...         ...        ...
# 502          2022                      48  33.997856   37.492907  40.327392
# 503          2022                      49  31.898066   34.741681  39.933947
# 504          2022                      50  30.683480   36.331698  48.045620
# 505          2022                      51  33.079122   37.545356  47.870999
# 506          2022                      52  30.294870   36.616075  56.900538
#
#        6,0+ KG  IKKE OPPGITT   Totalsum
# 0    13.256689           NaN  10.754267
# 1    13.346171           NaN  10.800751
# 2    13.249404           NaN  10.774089
# 3    13.247026           NaN  10.569605
# 4    13.311289           NaN  10.605343
# ..         ...           ...        ...
# 502  38.023946           NaN  39.417280
# 503  44.288580           NaN  39.071706
# 504  37.875704           NaN  42.701713
# 505  47.814482           NaN  43.652968
# 506  39.058437           NaN  49.076318
#
# [507 rows x 8 columns]

# %%
#KPI månedlig fra SSB:
POST_URL = 'https://data.ssb.no/api/v0/no/table/05327/'

# %%
payload = {
  "query": [
    {
      "code": "Konsumgrp",
      "selection": {
        "filter": "item",
        "values": [
          "JA_TOTAL"
        ]
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": [
          "KPIJustIndMnd"
        ]
      }
    },
    {
      "code": "Tid",
      "selection": {
        "filter": "item",
        "values": [
          "2013M03",
          "2013M04",
          "2013M05",
          "2013M06",
          "2013M07",
          "2013M08",
          "2013M09",
          "2013M10",
          "2013M11",
          "2013M12",
          "2014M01",
          "2014M02",
          "2014M03",
          "2014M04",
          "2014M05",
          "2014M06",
          "2014M07",
          "2014M08",
          "2014M09",
          "2014M10",
          "2014M11",
          "2014M12",
          "2015M01",
          "2015M02",
          "2015M03",
          "2015M04",
          "2015M05",
          "2015M06",
          "2015M07",
          "2015M08",
          "2015M09",
          "2015M10",
          "2015M11",
          "2015M12",
          "2016M01",
          "2016M02",
          "2016M03",
          "2016M04",
          "2016M05",
          "2016M06",
          "2016M07",
          "2016M08",
          "2016M09",
          "2016M10",
          "2016M11",
          "2016M12",
          "2017M01",
          "2017M02",
          "2017M03",
          "2017M04",
          "2017M05",
          "2017M06",
          "2017M07",
          "2017M08",
          "2017M09",
          "2017M10",
          "2017M11",
          "2017M12",
          "2018M01",
          "2018M02",
          "2018M03",
          "2018M04",
          "2018M05",
          "2018M06",
          "2018M07",
          "2018M08",
          "2018M09",
          "2018M10",
          "2018M11",
          "2018M12",
          "2019M01",
          "2019M02",
          "2019M03",
          "2019M04",
          "2019M05",
          "2019M06",
          "2019M07",
          "2019M08",
          "2019M09",
          "2019M10",
          "2019M11",
          "2019M12",
          "2020M01",
          "2020M02",
          "2020M03",
          "2020M04",
          "2020M05",
          "2020M06",
          "2020M07",
          "2020M08",
          "2020M09",
          "2020M10",
          "2020M11",
          "2020M12",
          "2021M01",
          "2021M02",
          "2021M03",
          "2021M04",
          "2021M05",
          "2021M06",
          "2021M07",
          "2021M08",
          "2021M09",
          "2021M10",
          "2021M11",
          "2021M12",
          "2022M01",
          "2022M02",
          "2022M03",
          "2022M04",
          "2022M05",
          "2022M06",
          "2022M07",
          "2022M08",
          "2022M09",
          "2022M10",
          "2022M11",
          "2022M12",
          "2023M01",
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}

# %%
result = requests.post(POST_URL, json = payload)

# %%
dataset = pyjstat.Dataset.read(result.text)
KPI_JA = dataset.write('dataframe')

# %%
KPI_JA
# Out:
#            konsumgruppe                                 statistikkvariabel  \
# 0    KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 1    KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 2    KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 3    KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 4    KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# ..                  ...                                                ...
# 114  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 115  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 116  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 117  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 118  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
#
#        måned  value
# 0    2013M03   95.4
# 1    2013M04   96.0
# 2    2013M05   96.1
# 3    2013M06   95.7
# 4    2013M07   96.1
# ..       ...    ...
# 114  2022M09  129.5
# 115  2022M10  128.8
# 116  2022M11  128.4
# 117  2022M12  129.6
# 118  2023M01  129.8
#
# [119 rows x 4 columns]

# %%
KPI = KPI_JA.value.head(-1)
KPI = pd.DataFrame(data=KPI)
KPI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   value   118 non-null    float64
# dtypes: float64(1)
# memory usage: 1.0 KB

# %%
KPI
# Out:
#      value
# 0     95.4
# 1     96.0
# 2     96.1
# 3     95.7
# 4     96.1
# ..     ...
# 113  127.2
# 114  129.5
# 115  128.8
# 116  128.4
# 117  129.6
#
# [118 rows x 1 columns]

# %%
dato_kpi = pd.date_range(start = '2013-03-01', end = '2022-12-31', freq = "m")

# %%
KPI = KPI.set_index(dato_kpi)

# %%
KPI
# Out:
#             value
# 2013-03-31   95.4
# 2013-04-30   96.0
# 2013-05-31   96.1
# 2013-06-30   95.7
# 2013-07-31   96.1
# ...           ...
# 2022-08-31  127.2
# 2022-09-30  129.5
# 2022-10-31  128.8
# 2022-11-30  128.4
# 2022-12-31  129.6
#
# [118 rows x 1 columns]

# %%
start_date = KPI.index.min() - pd.DateOffset(day=1)
end_date = KPI.index.max() + pd.DateOffset(day=31)

# %%
dates = pd.date_range(start_date, end_date, freq='w')
#dates.name = 'date'
KPI = KPI.reindex(dates, method='bfill')

# %%
KPI_mean = KPI.expanding().mean()

# %%
KPI
# Out:
#             value
# 2013-03-03   95.4
# 2013-03-10   95.4
# 2013-03-17   95.4
# 2013-03-24   95.4
# 2013-03-31   95.4
# ...           ...
# 2022-11-27  128.4
# 2022-12-04  129.6
# 2022-12-11  129.6
# 2022-12-18  129.6
# 2022-12-25  129.6
#
# [513 rows x 1 columns]

# %%
KPI.columns
# Out:
# Index(['value'], dtype='object')

# %%
KPI = KPI.rolling(window=4).mean().round(2)

# %%
KPI
# Out:
#             value
# 2013-03-03    NaN
# 2013-03-10    NaN
# 2013-03-17    NaN
# 2013-03-24   95.4
# 2013-03-31   95.4
# ...           ...
# 2022-11-27  128.4
# 2022-12-04  128.7
# 2022-12-11  129.0
# 2022-12-18  129.3
# 2022-12-25  129.6
#
# [513 rows x 1 columns]

# %%
KPI = KPI.tail(-5)
KPI = KPI.head(-1)

# %%
KPI
# Out:
#              value
# 2013-04-07   95.55
# 2013-04-14   95.70
# 2013-04-21   95.85
# 2013-04-28   96.00
# 2013-05-05   96.02
# ...            ...
# 2022-11-20  128.50
# 2022-11-27  128.40
# 2022-12-04  128.70
# 2022-12-11  129.00
# 2022-12-18  129.30
#
# [507 rows x 1 columns]

# %%
var_set = pd.DataFrame()

# %%
var_set["CPI"] = KPI["value"]

# %%
var_set["SalmonPrice"] = salmon_prices["Nasdaq 3-6 kg in FPI (FCA Oslo)"].to_numpy()

# %%
var_set["CodPrice"] = torsk_prices["Totalsum"].to_numpy()

# %%
var_set["HalibutPrice"] = kveite_prices["Totalsum"].to_numpy()

# %%
var_set = var_set.reindex(columns = [col for col in var_set.columns if col != 'CPI'] + ['CPI'])

# %%
df_curr = pd.read_csv("https://data.norges-bank.no/api/data/EXR/B.TWI.NOK.SP?format=csv&bom=include&apisrc=nbi&startPeriod=2013-04-01&endPeriod=2023-01-01&locale=no", delimiter=";", decimal=",", parse_dates=[14],index_col=[14])

# %%
df_curr = df_curr["OBS_VALUE"].resample("W").mean()

# %%
df_curr.drop(df_curr.tail(2).index,inplace=True)

# %%
df_curr
# Out:
# TIME_PERIOD
# 2013-04-07     92.1500
# 2013-04-14     92.1920
# 2013-04-21     92.7980
# 2013-04-28     93.8080
# 2013-05-05     93.3125
#                 ...
# 2022-11-20    122.2180
# 2022-11-27    122.0320
# 2022-12-04    120.8780
# 2022-12-11    122.7060
# 2022-12-18    122.3580
# Freq: W-SUN, Name: OBS_VALUE, Length: 507, dtype: float64

# %%
var_set["TWI"] = df_curr

# %%
var_set
# Out:
#             SalmonPrice   CodPrice  HalibutPrice     CPI       TWI
# 2013-04-07        39.63  10.754267     47.577612   95.55   92.1500
# 2013-04-14        41.89  10.800751     47.924958   95.70   92.1920
# 2013-04-21        43.07  10.774089     47.092639   95.85   92.7980
# 2013-04-28        42.70  10.569605     47.193296   96.00   93.8080
# 2013-05-05        41.81  10.605343     48.987917   96.02   93.3125
# ...                 ...        ...           ...     ...       ...
# 2022-11-20        82.49  39.417280     76.897925  128.50  122.2180
# 2022-11-27        79.03  39.071706     73.642666  128.40  122.0320
# 2022-12-04        78.05  42.701713     73.193629  128.70  120.8780
# 2022-12-11        75.83  43.652968     74.156841  129.00  122.7060
# 2022-12-18        86.64  49.076318     79.182888  129.30  122.3580
#
# [507 rows x 5 columns]

# %%
var_set.to_csv("var_set.csv")
